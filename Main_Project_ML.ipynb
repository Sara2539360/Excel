# %% [markdown]
# <a href="https://colab.research.google.com/github/Sara2539360/Excel/blob/main/Main_Project_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/Sara2539360/Stock-_Prediction-/refs/heads/main/ADP-Data.csv')

# %%
df.shape
# Out:
# (10752, 8)

# %%
df.head()
# Out:
#    Unnamed: 0        Date      High       Low  Open     Close     Volume  \
# 0           0  1980-03-17  0.927141  0.908554   0.0  0.917847  1158040.1
# 1           1  1980-03-18  0.930239  0.914749   0.0  0.927141  1622063.1
# 2           2  1980-03-19  0.942631  0.927141   0.0  0.942631  1367859.1
# 3           3  1980-03-20  0.961218  0.939533   0.0  0.939533  3046412.1
# 4           4  1980-03-21  0.948826  0.936435   0.0  0.936435  1020851.1
#
#    Adj Close
# 0   0.520855
# 1   0.525637
# 2   0.533608
# 3   0.532014
# 4   0.530420
